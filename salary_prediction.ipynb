# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Salary Data.csv")
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
#gives row and column
df.shape
# Out:
# (375, 6)

# %%
row,col = df.shape
print("No of rows = ", row)
print("No of cols = ", col)
# Out:
# No of rows =  375
# No of cols =  6

# %%
#numerical data ko mean, std and etc haru nikalne
df.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
#list all the empty data
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# dtype: int64

# %%
#drop all empty data rows
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 373 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Job Title            373 non-null    object
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 20.4+ KB

# %%
# extracts all the values from the 'Job Title' column of the DataFrame df and returns
# a set containing only the unique job titles.
set(df['Job Title'])
# Out:
# {'Account Manager',
#  'Accountant',
#  'Administrative Assistant',
#  'Business Analyst',
#  'Business Development Manager',
#  'Business Intelligence Analyst',
#  'CEO',
#  'Chief Data Officer',
#  'Chief Technology Officer',
#  'Content Marketing Manager',
#  'Copywriter',
#  'Creative Director',
#  'Customer Service Manager',
#  'Customer Service Rep',
#  'Customer Service Representative',
#  'Customer Success Manager',
#  'Customer Success Rep',
#  'Data Analyst',
#  'Data Entry Clerk',
#  'Data Scientist',
#  'Digital Content Producer',
#  'Digital Marketing Manager',
#  'Director',
#  'Director of Business Development',
#  'Director of Engineering',
#  'Director of Finance',
#  'Director of HR',
#  'Director of Human Capital',
#  'Director of Human Resources',
#  'Director of Marketing',
#  'Director of Operations',
#  'Director of Product Management',
#  'Director of Sales',
#  'Director of Sales and Marketing',
#  'Event Coordinator',
#  'Financial Advisor',
# ...

# %% [markdown]
# EDA

# %%
dataframe = df[['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
       'Salary']]

# %%
sns.pairplot(dataframe)

# %%
dataframe1 = df[['Age', 'Years of Experience','Salary']]
dataframe1.corr()
# Out:
#                           Age  Years of Experience    Salary
# Age                  1.000000             0.979128  0.922335
# Years of Experience  0.979128             1.000000  0.930338
# Salary               0.922335             0.930338  1.000000

# %% [markdown]
# high positive correlation coefficients suggest that these variables are strongly related to each other in a linear fashion.

# %%
import seaborn as sns
plt.figure(figsize=(15,5))
sns.heatmap(dataframe1.corr(),annot=True)
plt.show()

# %%
dataframe
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %% [markdown]
# Dimension Reduction

# %%
"""
Gender has two option male and female so we can convert it into a form the computer can understand
"""
gender = pd.get_dummies(dataframe['Gender'], drop_first=True)
gender

#we only need one column for gender since there are two options only so we drop the 1st column
# Out:
#       Male
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# ..     ...
# 370  False
# 371   True
# 372  False
# 373   True
# 374  False
#
# [373 rows x 1 columns]

# %%
dataframe = pd.concat([dataframe,gender], axis =1)
dataframe
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary   Male
# 0                    5.0   90000.0   True
# 1                    3.0   65000.0  False
# 2                   15.0  150000.0   True
# ...

# %%
#education has also three options so creating dummy values
education = pd.get_dummies(dataframe['Education Level'], drop_first=False)
education
# Out:
#      Bachelor's  Master's    PhD
# 0          True     False  False
# 1         False      True  False
# 2         False     False   True
# 3          True     False  False
# 4         False      True  False
# ..          ...       ...    ...
# 370        True     False  False
# 371       False      True  False
# 372        True     False  False
# 373        True     False  False
# 374       False     False   True
#
# [373 rows x 3 columns]

# %%
dataframe = pd.concat([dataframe,education], axis=1)
dataframe
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary   Male  Bachelor's  Master's    PhD
# 0                    5.0   90000.0   True        True     False  False
# ...

# %%
len(dataframe['Job Title'])
# Out:
# 373

# %%
len(set(dataframe['Job Title']))

# 174 unique job titles so creating dummy variables to represent this so computer can understand is
#impossible so we drop it
# Out:
# 174

# %%
dataframe = dataframe.drop(['Gender','Education Level','Job Title'], axis = 1)
dataframe
# Out:
#       Age  Years of Experience    Salary   Male  Bachelor's  Master's    PhD
# 0    32.0                  5.0   90000.0   True        True     False  False
# 1    28.0                  3.0   65000.0  False       False      True  False
# 2    45.0                 15.0  150000.0   True       False     False   True
# 3    36.0                  7.0   60000.0  False        True     False  False
# 4    52.0                 20.0  200000.0   True       False      True  False
# ..    ...                  ...       ...    ...         ...       ...    ...
# 370  35.0                  8.0   85000.0  False        True     False  False
# 371  43.0                 19.0  170000.0   True       False      True  False
# 372  29.0                  2.0   40000.0  False        True     False  False
# 373  34.0                  7.0   90000.0   True        True     False  False
# 374  44.0                 15.0  150000.0  False       False     False   True
#
# [373 rows x 7 columns]

# %%
dataframe.corr()

# The correlation of being Male with Age, Years of Experience, and Salary is relatively low,
#  suggesting gender does not strongly correlate with these factors in this dataset so it can be dropped.
# Out:
#                           Age  Years of Experience    Salary      Male  \
# Age                  1.000000             0.979128  0.922335 -0.020324
# Years of Experience  0.979128             1.000000  0.930338  0.002884
# Salary               0.922335             0.930338  1.000000  0.071106
# Male                -0.020324             0.002884  0.071106  1.000000
# Bachelor's          -0.541733            -0.573775 -0.657181  0.049259
# Master's             0.281897             0.306961  0.362061 -0.036219
# PhD                  0.411183             0.424752  0.473073 -0.023827
#
#                      Bachelor's  Master's       PhD
# Age                   -0.541733  0.281897  0.411183
# Years of Experience   -0.573775  0.306961  0.424752
# Salary                -0.657181  0.362061  0.473073
# Male                   0.049259 -0.036219 -0.023827
# Bachelor's             1.000000 -0.731944 -0.487964
# Master's              -0.731944  1.000000 -0.237577
# ...

# %%
import seaborn as sns
plt.figure(figsize=(15,5))
sns.heatmap(dataframe.corr(),annot=True)
plt.show()

# %%
sns.pairplot(dataframe)

# %%
dataframe = dataframe.drop(['Male'], axis = 1)
dataframe
# Out:
#       Age  Years of Experience    Salary  Bachelor's  Master's    PhD
# 0    32.0                  5.0   90000.0        True     False  False
# 1    28.0                  3.0   65000.0       False      True  False
# 2    45.0                 15.0  150000.0       False     False   True
# 3    36.0                  7.0   60000.0        True     False  False
# 4    52.0                 20.0  200000.0       False      True  False
# ..    ...                  ...       ...         ...       ...    ...
# 370  35.0                  8.0   85000.0        True     False  False
# 371  43.0                 19.0  170000.0       False      True  False
# 372  29.0                  2.0   40000.0        True     False  False
# 373  34.0                  7.0   90000.0        True     False  False
# 374  44.0                 15.0  150000.0       False     False   True
#
# [373 rows x 6 columns]

# %%
#converting salary data to int
dataframe['Salary'] = dataframe['Salary'].astype('int')
dataframe
# Out:
#       Age  Years of Experience  Salary  Bachelor's  Master's    PhD
# 0    32.0                  5.0   90000        True     False  False
# 1    28.0                  3.0   65000       False      True  False
# 2    45.0                 15.0  150000       False     False   True
# 3    36.0                  7.0   60000        True     False  False
# 4    52.0                 20.0  200000       False      True  False
# ..    ...                  ...     ...         ...       ...    ...
# 370  35.0                  8.0   85000        True     False  False
# 371  43.0                 19.0  170000       False      True  False
# 372  29.0                  2.0   40000        True     False  False
# 373  34.0                  7.0   90000        True     False  False
# 374  44.0                 15.0  150000       False     False   True
#
# [373 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
df_train,df_test = train_test_split(dataframe, train_size=0.85, test_size=0.15, random_state = 1)

# %%
df_train
# Out:
#       Age  Years of Experience  Salary  Bachelor's  Master's    PhD
# 160  39.0                 12.0   90000        True     False  False
# 361  34.0                  7.0   90000        True     False  False
# 180  29.0                  2.0   40000        True     False  False
# 344  44.0                 16.0  160000       False     False   True
# 291  49.0                 21.0  180000       False     False   True
# ..    ...                  ...     ...         ...       ...    ...
# 204  36.0                  7.0   90000        True     False  False
# 256  34.0                  6.0  100000       False      True  False
# 72   45.0                 16.0  190000       False     False   True
# 236  37.0                  9.0  100000        True     False  False
# 37   42.0                 14.0  115000       False      True  False
#
# [317 rows x 6 columns]

# %%
df_test
# Out:
#       Age  Years of Experience  Salary  Bachelor's  Master's    PhD
# 67   31.0                  5.0   45000        True     False  False
# 348  28.0                  1.0   35000        True     False  False
# 343  41.0                 14.0  150000        True     False  False
# 295  33.0                  4.0   60000        True     False  False
# 90   36.0                 11.0  120000       False     False   True
# 298  30.0                  2.0   40000        True     False  False
# 167  46.0                 18.0  150000       False     False   True
# 323  47.0                 20.0  180000       False     False   True
# 65   38.0                 10.0   90000       False      True  False
# 150  29.0                  3.0   45000        True     False  False
# 314  35.0                  8.0   85000        True     False  False
# 171  29.0                  2.0   40000        True     False  False
# 190  39.0                 12.0   95000        True     False  False
# ...

# %%
df_train.shape
# Out:
# (317, 6)

# %%
df_test.shape
# Out:
# (56, 6)

# %%
from sklearn.linear_model import LinearRegression
X_train = df_train[['Age','Years of Experience',"Bachelor's",
                    "Master's","PhD"]]

Y_train = df_train['Salary']


# for linear regression
lr = LinearRegression()
lr_model = lr.fit(X_train, Y_train)

# for logistic regression
from sklearn.linear_model import LogisticRegression
lg = LogisticRegression()
lg_model = lg.fit(X_train, Y_train)

# for polynomial regression
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=8)
X_poly = poly_reg.fit_transform(X_train)  # transform training data into polynomial features

poly = LinearRegression()  
poly_model = poly.fit(X_poly, Y_train)  #fits the linear regression model using the polynomial features
# Out:
# c:\Users\sushantbro\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
data = df_test.iloc[50:51]
actual_salary = data['Salary']
data = data.drop(['Salary'],axis = 1)
data
# Out:
#       Age  Years of Experience  Bachelor's  Master's    PhD
# 354  31.0                  3.0        True     False  False

# %%
#linear model
print("Predicted Salary",lr_model.predict(data))
print("Actual Salary",actual_salary)
# Out:
# Predicted Salary [53934.59717459]
# Actual Salary 354    50000
# Name: Salary, dtype: int64

# %%
#logistic
print("Predicted Salary",lg_model.predict(data))
print("Actual Salary",actual_salary)
# Out:
# Predicted Salary [40000]
# Actual Salary 354    50000
# Name: Salary, dtype: int64

# %%
#polynomial regression 
data1 = poly_reg.fit_transform(data) #transforms this new data into the same polynomial feature space that was used to train poly_model.
predicted_salary = poly_model.predict(data1)
print("Actual Salary",actual_salary)
print("predicted Salary",predicted_salary)
# Out:
# Actual Salary 354    50000
# Name: Salary, dtype: int64
# predicted Salary [48218.98077431]

# %%
#train acc
print("Linear regression = ",lr_model.score(X_train,Y_train)*100)
print("Logistic regression = ",lg_model.score(X_train, Y_train)*100)
print("Polynomial regression = ",poly_model.score(poly_reg.fit_transform(X_train), Y_train)*100)
# Out:
# Linear regression =  89.00649825144669
# Logistic regression =  31.230283911671926
# Polynomial regression =  93.3680383942374

# %%
#test acc
test_data = df_test
Y_test = test_data['Salary']
X_test = test_data.drop(['Salary'],axis = 1)

print("Linear regression = ",lr_model.score(X_test, Y_test)*100)
print("Logistic regression = ",lg_model.score(X_test, Y_test)*100)
print("Polynomial regression = ",poly_model.score(poly_reg.fit_transform(X_test), Y_test)*100)
# Out:
# Linear regression =  92.02629659718285
# Logistic regression =  23.214285714285715
# Polynomial regression =  -10036.530037961777

# %%
# Testing
data = df_test.iloc[50:51]
actual_salary = data.pop('Salary')

# # # print(data)
predicted_salary = poly_model.predict(poly_reg.fit_transform(data))
print("Actual Salary",actual_salary)
print("predicted Salary",predicted_salary)
data
# Out:
# Actual Salary 354    50000
# Name: Salary, dtype: int64
# predicted Salary [48218.98077431]
#       Age  Years of Experience  Bachelor's  Master's    PhD
# 354  31.0                  3.0        True     False  False

# %%
data = {'Age':[int(input("Enter your age = "))],
        'Years of Experience':[float(input("Enter Experience = "))],
        "Bachelor's":[int(input("Enter 1 for Bac and 0 for other = "))],
        "Master's":[int(input("Enter 1 for Mast and 0 for other = "))],
        "PhD":[int(input("Enter 1 for PhD and 0 for other = "))]}

df = pd.DataFrame(data)

predicted_salary = lr_model.predict(df)

print("predicted Salary",np.round(predicted_salary,2))
df
# Out:
# predicted Salary [45592.46]
#    Age  Years of Experience  Bachelor's  Master's  PhD
# 0   25                  5.0           1         0    0

# %%
plt.scatter(Y_train,lr_model.predict(X_train),color = 'red')
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.show()

# %%
plt.scatter(Y_train,lg_model.predict(X_train),color = 'red')
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.show()

# %%
plt.scatter(Y_train,poly_model.predict(poly_reg.fit_transform(X_train)),color = 'red')
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
plt.show()
