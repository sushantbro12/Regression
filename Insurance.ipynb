# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Insurance.csv")
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]>

# %%
dataframe = df

# %%
sns.pairplot(dataframe)

# %%
dataframe1 = df[['age','bmi','children','expenses']]
dataframe1.corr()
# Out:
#                age       bmi  children  expenses
# age       1.000000  0.109341  0.042469  0.299008
# bmi       0.109341  1.000000  0.012645  0.198576
# children  0.042469  0.012645  1.000000  0.067998
# expenses  0.299008  0.198576  0.067998  1.000000

# %%
import seaborn as sns
plt.figure(figsize=(15,5))
sns.heatmap(dataframe1.corr(),annot=True)
plt.show()

# %%
dataframe
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %% [markdown]
# Dimension Reduction

# %%
sex = pd.get_dummies(dataframe['sex'], drop_first=True)
sex
# Out:
#        male
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# ...     ...
# 1333   True
# 1334  False
# 1335  False
# 1336  False
# 1337  False
#
# [1338 rows x 1 columns]

# %%
dataframe = pd.concat([dataframe,sex], axis =1)
dataframe
# Out:
#       age     sex   bmi  children smoker     region  expenses   male
# 0      19  female  27.9         0    yes  southwest  16884.92  False
# 1      18    male  33.8         1     no  southeast   1725.55   True
# 2      28    male  33.0         3     no  southeast   4449.46   True
# 3      33    male  22.7         0     no  northwest  21984.47   True
# 4      32    male  28.9         0     no  northwest   3866.86   True
# ...   ...     ...   ...       ...    ...        ...       ...    ...
# 1333   50    male  31.0         3     no  northwest  10600.55   True
# 1334   18  female  31.9         0     no  northeast   2205.98  False
# 1335   18  female  36.9         0     no  southeast   1629.83  False
# 1336   21  female  25.8         0     no  southwest   2007.95  False
# 1337   61  female  29.1         0    yes  northwest  29141.36  False
#
# [1338 rows x 8 columns]

# %%
smoker = pd.get_dummies(dataframe['smoker'], drop_first=True)
smoker
# Out:
#         yes
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 1333  False
# 1334  False
# 1335  False
# 1336  False
# 1337   True
#
# [1338 rows x 1 columns]

# %%
smoker = smoker.rename(columns={'yes':'smoke'})
smoker
# Out:
#       smoke
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 1333  False
# 1334  False
# 1335  False
# 1336  False
# 1337   True
#
# [1338 rows x 1 columns]

# %%
dataframe = pd.concat([dataframe,smoker], axis =1)
dataframe
# Out:
#       age     sex   bmi  children smoker     region  expenses   male  smoke
# 0      19  female  27.9         0    yes  southwest  16884.92  False   True
# 1      18    male  33.8         1     no  southeast   1725.55   True  False
# 2      28    male  33.0         3     no  southeast   4449.46   True  False
# 3      33    male  22.7         0     no  northwest  21984.47   True  False
# 4      32    male  28.9         0     no  northwest   3866.86   True  False
# ...   ...     ...   ...       ...    ...        ...       ...    ...    ...
# 1333   50    male  31.0         3     no  northwest  10600.55   True  False
# 1334   18  female  31.9         0     no  northeast   2205.98  False  False
# 1335   18  female  36.9         0     no  southeast   1629.83  False  False
# 1336   21  female  25.8         0     no  southwest   2007.95  False  False
# 1337   61  female  29.1         0    yes  northwest  29141.36  False   True
#
# [1338 rows x 9 columns]

# %%
region = pd.get_dummies(dataframe['region'])
region
# Out:
#       northeast  northwest  southeast  southwest
# 0         False      False      False       True
# 1         False      False       True      False
# 2         False      False       True      False
# 3         False       True      False      False
# 4         False       True      False      False
# ...         ...        ...        ...        ...
# 1333      False       True      False      False
# 1334       True      False      False      False
# 1335      False      False       True      False
# 1336      False      False      False       True
# 1337      False       True      False      False
#
# [1338 rows x 4 columns]

# %%
dataframe = pd.concat([dataframe,region], axis =1)
dataframe
# Out:
#       age     sex   bmi  children smoker     region  expenses   male  smoke  \
# 0      19  female  27.9         0    yes  southwest  16884.92  False   True
# 1      18    male  33.8         1     no  southeast   1725.55   True  False
# 2      28    male  33.0         3     no  southeast   4449.46   True  False
# 3      33    male  22.7         0     no  northwest  21984.47   True  False
# 4      32    male  28.9         0     no  northwest   3866.86   True  False
# ...   ...     ...   ...       ...    ...        ...       ...    ...    ...
# 1333   50    male  31.0         3     no  northwest  10600.55   True  False
# 1334   18  female  31.9         0     no  northeast   2205.98  False  False
# 1335   18  female  36.9         0     no  southeast   1629.83  False  False
# 1336   21  female  25.8         0     no  southwest   2007.95  False  False
# 1337   61  female  29.1         0    yes  northwest  29141.36  False   True
#
#       northeast  northwest  southeast  southwest
# ...

# %%
dataframe = dataframe.drop(['sex','smoker','region'], axis = 1)
dataframe
# Out:
#       age   bmi  children  expenses   male  smoke  northeast  northwest  \
# 0      19  27.9         0  16884.92  False   True      False      False
# 1      18  33.8         1   1725.55   True  False      False      False
# 2      28  33.0         3   4449.46   True  False      False      False
# 3      33  22.7         0  21984.47   True  False      False       True
# 4      32  28.9         0   3866.86   True  False      False       True
# ...   ...   ...       ...       ...    ...    ...        ...        ...
# 1333   50  31.0         3  10600.55   True  False      False       True
# 1334   18  31.9         0   2205.98  False  False       True      False
# 1335   18  36.9         0   1629.83  False  False      False      False
# 1336   21  25.8         0   2007.95  False  False      False      False
# 1337   61  29.1         0  29141.36  False   True      False       True
#
#       southeast  southwest
# 0         False       True
# 1          True      False
# ...

# %%
dataframe.corr()
# Out:
#                 age       bmi  children  expenses      male     smoke  \
# age        1.000000  0.109341  0.042469  0.299008 -0.020856 -0.025019
# bmi        0.109341  1.000000  0.012645  0.198576  0.046380  0.003968
# children   0.042469  0.012645  1.000000  0.067998  0.017163  0.007673
# expenses   0.299008  0.198576  0.067998  1.000000  0.057292  0.787251
# male      -0.020856  0.046380  0.017163  0.057292  1.000000  0.076185
# smoke     -0.025019  0.003968  0.007673  0.787251  0.076185  1.000000
# northeast  0.002475 -0.138091 -0.022808  0.006349 -0.002425  0.002811
# northwest -0.000407 -0.135992  0.024806 -0.039905 -0.011156 -0.036945
# southeast -0.011642  0.270144 -0.023066  0.073982  0.017117  0.068498
# southwest  0.010016 -0.006398  0.021914 -0.043210 -0.004184 -0.036945
#
#            northeast  northwest  southeast  southwest
# age         0.002475  -0.000407  -0.011642   0.010016
# bmi        -0.138091  -0.135992   0.270144  -0.006398
# ...

# %%
import seaborn as sns
plt.figure(figsize=(15,5))
sns.heatmap(dataframe.corr(),annot=True)
plt.show()

# %%
#dropping due to low corellation with target varaiable
dataframe = dataframe.drop(['children', 'male', 'northeast', 'northwest', 'southeast','southwest'], axis = 1)
dataframe
# Out:
#       age   bmi  expenses  smoke
# 0      19  27.9  16884.92   True
# 1      18  33.8   1725.55  False
# 2      28  33.0   4449.46  False
# 3      33  22.7  21984.47  False
# 4      32  28.9   3866.86  False
# ...   ...   ...       ...    ...
# 1333   50  31.0  10600.55  False
# 1334   18  31.9   2205.98  False
# 1335   18  36.9   1629.83  False
# 1336   21  25.8   2007.95  False
# 1337   61  29.1  29141.36   True
#
# [1338 rows x 4 columns]

# %%
#converting expenses data to int
dataframe['expenses'] = dataframe['expenses'].astype('int')
dataframe
# Out:
#       age   bmi  expenses  smoke
# 0      19  27.9     16884   True
# 1      18  33.8      1725  False
# 2      28  33.0      4449  False
# 3      33  22.7     21984  False
# 4      32  28.9      3866  False
# ...   ...   ...       ...    ...
# 1333   50  31.0     10600  False
# 1334   18  31.9      2205  False
# 1335   18  36.9      1629  False
# 1336   21  25.8      2007  False
# 1337   61  29.1     29141   True
#
# [1338 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
df_train,df_test = train_test_split(dataframe, train_size=0.85, test_size=0.15, random_state = 1)

# %%
df_train
# Out:
#       age   bmi  expenses  smoke
# 215    41  37.1      7371  False
# 1035   54  23.0     12094  False
# 1211   39  34.1     23563  False
# 1173   38  29.3      6457  False
# 236    18  26.7      1615  False
# ...   ...   ...       ...    ...
# 715    60  28.9     12146  False
# 905    26  29.4      4564  False
# 1096   51  35.0     44641   True
# 235    40  22.2     19444   True
# 1061   57  27.9     11554  False
#
# [1137 rows x 4 columns]

# %%
df_test
# Out:
#       age   bmi  expenses  smoke
# 559    19  35.5      1646  False
# 1087   57  31.5     11353  False
# 1020   51  37.0      8798  False
# 460    49  36.6     10381  False
# 802    21  22.3      2103  False
# ...   ...   ...       ...    ...
# 891    36  29.0      7243  False
# 414    19  35.2      2134  False
# 258    51  24.4     11520  False
# 538    46  28.1      8233  False
# 929    41  34.2      6289  False
#
# [201 rows x 4 columns]

# %%
df_train.shape
# Out:
# (1137, 4)

# %%
df_test.shape
# Out:
# (201, 4)

# %%
from sklearn.linear_model import LinearRegression
X_train = df_train[['age','bmi',"smoke"]]

Y_train = df_train['expenses']


# for linear regression
lr = LinearRegression()
lr_model = lr.fit(X_train, Y_train)

# for logistic regression
from sklearn.linear_model import LogisticRegression
lg = LogisticRegression()
lg_model = lg.fit(X_train, Y_train)

# for polynomial regression
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=8)
X_poly = poly_reg.fit_transform(X_train)  # transform training data into polynomial features

poly = LinearRegression()  
poly_model = poly.fit(X_poly, Y_train)  #fits the linear regression model using the polynomial features
# Out:
# c:\Users\sushantbro\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
data = df_test.iloc[50:51]
actual_expenses = data['expenses']
data = data.drop(['expenses'],axis = 1)
data
# Out:
#      age   bmi  smoke
# 190   61  31.6  False

# %%
#linear model
print("Predicted expenses",lr_model.predict(data))
print("Actual expenses",actual_expenses)
# Out:
# Predicted expenses [14372.97247094]
# Actual expenses 190    12557
# Name: expenses, dtype: int64

# %%
#logistic
print("Predicted expenses",lg_model.predict(data))
print("Actual expenses",actual_expenses)
# Out:
# Predicted expenses [11842]
# Actual expenses 190    12557
# Name: expenses, dtype: int64

# %%
#polynomial regression 
data1 = poly_reg.fit_transform(data) #transforms this new data into the same polynomial feature space that was used to train poly_model.
predicted_expenses = poly_model.predict(data1)
print("Actual expenses",actual_expenses)
print("predicted expenses",predicted_expenses)
# Out:
# Actual expenses 190    12557
# Name: expenses, dtype: int64
# predicted expenses [14638.86769315]

# %%
#train acc
print("Linear regression = ",lr_model.score(X_train,Y_train)*100)
print("Logistic regression = ",lg_model.score(X_train, Y_train)*100)
print("Polynomial regression = ",poly_model.score(poly_reg.fit_transform(X_train), Y_train)*100)
# Out:
# Linear regression =  74.88296186662102
# Logistic regression =  2.9023746701846966
# Polynomial regression =  85.89477850480647

# %%
#test acc
test_data = df_test
Y_test = test_data['expenses']
X_test = test_data.drop(['expenses'],axis = 1)

print("Linear regression = ",lr_model.score(X_test, Y_test)*100)
print("Logistic regression = ",lg_model.score(X_test, Y_test)*100)
print("Polynomial regression = ",poly_model.score(poly_reg.fit_transform(X_test), Y_test)*100)
# Out:
# Linear regression =  73.9440981324773
# Logistic regression =  0.0
# Polynomial regression =  85.74914581852566

# %%
# Testing
data = df_test.iloc[50:51]
actual_expenses = data.pop('expenses')

# # # print(data)
predicted_expenses = poly_model.predict(poly_reg.fit_transform(data))
print("Actual expenses",actual_expenses)
print("predicted Salary",predicted_expenses)
data
# Out:
# Actual expenses 190    12557
# Name: expenses, dtype: int64
# predicted Salary [14638.86769315]
#      age   bmi  smoke
# 190   61  31.6  False

# %%
plt.scatter(Y_train,lr_model.predict(X_train),color = 'red')
plt.xlabel('Actual expenses')
plt.ylabel('Predicted expenses')
plt.show()

# %%
plt.scatter(Y_train,lg_model.predict(X_train),color = 'red')
plt.xlabel('Actual expenses')
plt.ylabel('Predicted expenses')
plt.show()

# %%
plt.scatter(Y_train,poly_model.predict(poly_reg.fit_transform(X_train)),color = 'red')
plt.xlabel('Actual expenses')
plt.ylabel('Predicted expenses')
plt.show()
